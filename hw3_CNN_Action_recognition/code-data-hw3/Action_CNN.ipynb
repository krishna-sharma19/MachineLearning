# %% [markdown]
# # Training a ConvNet PyTorch
#
# In this notebook, you'll learn how to use the powerful PyTorch framework to specify a conv net architecture and train it on the human action recognition dataset.

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.autograd import Variable
from torch.utils.data import DataLoader,sampler,Dataset
import torchvision.datasets as dset
import torchvision.transforms as T
import timeit
from PIL import Image
import os
import numpy as np
import scipy.io
import torchvision

# %% [markdown]
# ## What's this PyTorch business?
#
# * When using a framework like PyTorch or TensorFlow you can harness the power of the GPU for your own custom neural network architectures without having to write CUDA code directly.
# * this notebook will walk you through much of what you need to do to train models using pytorch. if you want to learn more or need further clarification on topics that aren't fully explained here, here are 2 good Pytorch tutorials. 1): http://pytorch.org/tutorials/beginner/deep_learning_60min_blitz.html 2)http://pytorch.org/tutorials/beginner/pytorch_with_examples.html
# * It's not necessary to have a GPU for this homework, using a GPU can make your code run faster.

# %% [markdown]
# ## Load Datasets
#
# In this part, we will load the action recognition dataset for the neural network. In order to load data from our custom dataset, we need to write a custom Dataloader. If you put q3_2_data.mat, /valClips,/trainClips,/testClips under the folder of ./data/ , you do not need to change anything in this part.

# %% [markdown]
# First, load the labels of the dataset, you should write your path of the q3_2_data.mat file.

# %%
label_mat=scipy.io.loadmat('./data/q3_2_data.mat')
label_train=label_mat['trLb']
print(len(label_train))
label_val=label_mat['valLb']
print(len(label_val))
# Out:
# 7770
# 2230

# %% [markdown]
# ### Dataset class
#
# torch.utils.data.Dataset is an abstract class representing a dataset. The custom dataset should inherit Dataset and override the following methods:
#
#     __len__ so that len(dataset) returns the size of the dataset.
#     __getitem__ to support the indexing such that dataset[i] can be used to get ith sample
#
# Let’s create a dataset class for our action recognition dataset. We will read images in __getitem__. This is memory efficient because all the images are not stored in the memory at once but read as required.
#
# Sample of our dataset will be a dict {'image':image,'img_path':img_path,'Label':Label}. Our datset will take an optional argument transform so that any required processing can be applied on the sample.

# %%
class ActionDataset(Dataset):
    """Action dataset."""

    def __init__(self,  root_dir,labels=[], transform=None):
        """
        Args:
            root_dir (string): Directory with all the images.
            labels(list): labels if images.
            transform (callable, optional): Optional transform to be applied on a sample.
        """
        self.root_dir = root_dir
        self.transform = transform
        self.length=len(os.listdir(self.root_dir))
        self.labels=labels
    def __len__(self):
        return self.length*3

    def __getitem__(self, idx):
        
        folder=idx/3+1
        imidx=idx%3+1
        folder=format(folder,'05d')
        imgname=str(imidx)+'.jpg'
        img_path = os.path.join(self.root_dir,
                                folder,imgname)
        image = Image.open(img_path)
        if len(self.labels)!=0:
            Label=self.labels[idx/3][0]-1
        if self.transform:
            image = self.transform(image)
        if len(self.labels)!=0:
            sample={'image':image,'img_path':img_path,'Label':Label}
        else:
            sample={'image':image,'img_path':img_path}
        return sample

# %% [markdown]
# Iterating over the dataset by a for loop.

# %%
image_dataset=ActionDataset(root_dir='./data/trainClips/',\
                            labels=label_train,transform=T.ToTensor())



#iterating though the dataset
for i in range(10):
    sample=image_dataset[i]
    print(sample['image'].shape)
    print(sample['Label'])
    print(sample['img_path'])
# Out:
# torch.Size([3, 64, 64])
# 0.0
# ./data/trainClips/00001/1.jpg
# torch.Size([3, 64, 64])
# 0.0
# ./data/trainClips/00001/2.jpg
# torch.Size([3, 64, 64])
# 0.0
# ./data/trainClips/00001/3.jpg
# torch.Size([3, 64, 64])
# 0.0
# ./data/trainClips/00002/1.jpg
# torch.Size([3, 64, 64])
# 0.0
# ./data/trainClips/00002/2.jpg
# torch.Size([3, 64, 64])
# 0.0
# ./data/trainClips/00002/3.jpg
# torch.Size([3, 64, 64])
# 0.0
# ./data/trainClips/00003/1.jpg
# torch.Size([3, 64, 64])
# 0.0
# ./data/trainClips/00003/2.jpg
# torch.Size([3, 64, 64])
# 0.0
# ./data/trainClips/00003/3.jpg
# torch.Size([3, 64, 64])
# 0.0
# ./data/trainClips/00004/1.jpg

# %% [markdown]
# We can iterate over the created dataset with a 'for' loop as before. However, we are losing a lot of features by using a simple for loop to iterate over the data. In particular, we are missing out on:
#
# * Batching the data
# * Shuffling the data
# * Load the data in parallel using multiprocessing workers.
#
# torch.utils.data.DataLoader is an iterator which provides all these features.

# %%
image_dataloader = DataLoader(image_dataset, batch_size=4,
                        shuffle=True, num_workers=4)


for i,sample in enumerate(image_dataloader):
    sample['image']=sample['image']#.cuda()
    print(i,sample['image'].shape,sample['img_path'],sample['Label'])
    if i>20: 
        break
# Out:
# (0, torch.Size([4, 3, 64, 64]), ['./data/trainClips/04792/2.jpg', './data/trainClips/07385/1.jpg', './data/trainClips/02985/1.jpg', './data/trainClips/06034/1.jpg'],
#  5
#  9
#  3
#  7
# [torch.DoubleTensor of size 4]
# )
# (1, torch.Size([4, 3, 64, 64]), ['./data/trainClips/04853/1.jpg', './data/trainClips/02042/2.jpg', './data/trainClips/00889/3.jpg', './data/trainClips/00024/2.jpg'],
#  5
#  2
#  0
#  0
# [torch.DoubleTensor of size 4]
# )
# (2, torch.Size([4, 3, 64, 64]), ['./data/trainClips/03822/3.jpg', './data/trainClips/04488/3.jpg', './data/trainClips/04279/2.jpg', './data/trainClips/03395/2.jpg'],
#  4
#  5
#  5
#  3
# [torch.DoubleTensor of size 4]
# )
# (3, torch.Size([4, 3, 64, 64]), ['./data/trainClips/02782/3.jpg', './data/trainClips/00831/1.jpg', './data/trainClips/06848/2.jpg', './data/trainClips/02453/1.jpg'],
#  3
#  0
#  8
#  2
# [torch.DoubleTensor of size 4]
# )
# (4, torch.Size([4, 3, 64, 64]), ['./data/trainClips/05440/3.jpg', './data/trainClips/04200/1.jpg', './data/trainClips/00768/2.jpg', './data/trainClips/04919/3.jpg'],
#  6
#  5
#  0
#  5
# [torch.DoubleTensor of size 4]
# )
# (5, torch.Size([4, 3, 64, 64]), ['./data/trainClips/01305/3.jpg', './data/trainClips/02464/3.jpg', './data/trainClips/05193/3.jpg', './data/trainClips/06421/2.jpg'],
#  1
#  2
#  6
#  7
# [torch.DoubleTensor of size 4]
# )
# (6, torch.Size([4, 3, 64, 64]), ['./data/trainClips/07430/3.jpg', './data/trainClips/01906/2.jpg', './data/trainClips/04754/1.jpg', './data/trainClips/07380/1.jpg'],
#  9
#  2
#  5
#  9
# [torch.DoubleTensor of size 4]
# )
# (7, torch.Size([4, 3, 64, 64]), ['./data/trainClips/04727/2.jpg', './data/trainClips/07192/3.jpg', './data/trainClips/00339/3.jpg', './data/trainClips/01665/3.jpg'],
#  5
#  9
#  0
#  1
# [torch.DoubleTensor of size 4]
# )
# (8, torch.Size([4, 3, 64, 64]), ['./data/trainClips/00011/1.jpg', './data/trainClips/01346/1.jpg', './data/trainClips/04369/2.jpg', './data/trainClips/02090/2.jpg'],
#  0
#  1
#  5
#  2
# [torch.DoubleTensor of size 4]
# )
# (9, torch.Size([4, 3, 64, 64]), ['./data/trainClips/01343/1.jpg', './data/trainClips/04329/1.jpg', './data/trainClips/00813/1.jpg', './data/trainClips/03957/3.jpg'],
#  1
#  5
#  0
#  4
# [torch.DoubleTensor of size 4]
# )
# (10, torch.Size([4, 3, 64, 64]), ['./data/trainClips/01670/3.jpg', './data/trainClips/01404/1.jpg', './data/trainClips/07703/2.jpg', './data/trainClips/01709/3.jpg'],
#  1
#  1
#  9
#  1
# [torch.DoubleTensor of size 4]
# )
# (11, torch.Size([4, 3, 64, 64]), ['./data/trainClips/02546/2.jpg', './data/trainClips/03560/3.jpg', './data/trainClips/05574/1.jpg', './data/trainClips/00429/2.jpg'],
#  2
#  4
#  6
#  0
# [torch.DoubleTensor of size 4]
# )
# (12, torch.Size([4, 3, 64, 64]), ['./data/trainClips/03754/1.jpg', './data/trainClips/05550/2.jpg', './data/trainClips/06494/3.jpg', './data/trainClips/01318/3.jpg'],
#  4
#  6
#  8
#  1
# [torch.DoubleTensor of size 4]
# )
# (13, torch.Size([4, 3, 64, 64]), ['./data/trainClips/06508/1.jpg', './data/trainClips/06367/2.jpg', './data/trainClips/03614/1.jpg', './data/trainClips/05763/1.jpg'],
#  8
#  7
#  4
#  7
# [torch.DoubleTensor of size 4]
# )
# (14, torch.Size([4, 3, 64, 64]), ['./data/trainClips/00805/1.jpg', './data/trainClips/05108/3.jpg', './data/trainClips/00930/3.jpg', './data/trainClips/05436/1.jpg'],
#  0
#  6
#  1
#  6
# [torch.DoubleTensor of size 4]
# )
# (15, torch.Size([4, 3, 64, 64]), ['./data/trainClips/04663/2.jpg', './data/trainClips/04159/2.jpg', './data/trainClips/02418/2.jpg', './data/trainClips/03965/1.jpg'],
#  5
#  4
#  2
#  4
# [torch.DoubleTensor of size 4]
# )
# (16, torch.Size([4, 3, 64, 64]), ['./data/trainClips/05377/2.jpg', './data/trainClips/03331/2.jpg', './data/trainClips/07658/2.jpg', './data/trainClips/02590/2.jpg'],
#  6
#  3
#  9
#  2
# [torch.DoubleTensor of size 4]
# )
# (17, torch.Size([4, 3, 64, 64]), ['./data/trainClips/03534/2.jpg', './data/trainClips/00071/2.jpg', './data/trainClips/07002/3.jpg', './data/trainClips/00840/3.jpg'],
#  4
#  0
#  8
#  0
# [torch.DoubleTensor of size 4]
# )
# (18, torch.Size([4, 3, 64, 64]), ['./data/trainClips/04515/2.jpg', './data/trainClips/07454/3.jpg', './data/trainClips/04801/1.jpg', './data/trainClips/03047/3.jpg'],
#  5
#  9
#  5
#  3
# [torch.DoubleTensor of size 4]
# )
# (19, torch.Size([4, 3, 64, 64]), ['./data/trainClips/07558/2.jpg', './data/trainClips/04505/2.jpg', './data/trainClips/06399/3.jpg', './data/trainClips/03976/1.jpg'],
#  9
#  5
#  7
#  4
# [torch.DoubleTensor of size 4]
# )
# (20, torch.Size([4, 3, 64, 64]), ['./data/trainClips/05224/2.jpg', './data/trainClips/00665/1.jpg', './data/trainClips/07431/3.jpg', './data/trainClips/00442/2.jpg'],
#  6
#  0
#  9
#  0
# [torch.DoubleTensor of size 4]
# )
# (21, torch.Size([4, 3, 64, 64]), ['./data/trainClips/04689/1.jpg', './data/trainClips/02713/2.jpg', './data/trainClips/00028/3.jpg', './data/trainClips/02338/3.jpg'],
#  5
#  3
#  0
#  2
# [torch.DoubleTensor of size 4]
# )

# %% [markdown]
# Dataloaders for the training, validationg and testing set.

# %%
image_dataset_train=ActionDataset(root_dir='./data/trainClips/',labels=label_train,transform=T.ToTensor())

image_dataloader_train = DataLoader(image_dataset_train, batch_size=32,
                        shuffle=True, num_workers=4)
image_dataset_val=ActionDataset(root_dir='./data/valClips/',labels=label_val,transform=T.ToTensor())

image_dataloader_val = DataLoader(image_dataset_val, batch_size=32,
                        shuffle=False, num_workers=4)
image_dataset_test=ActionDataset(root_dir='./data/testClips/',labels=[],transform=T.ToTensor())

image_dataloader_test = DataLoader(image_dataset_test, batch_size=32,
                        shuffle=False, num_workers=4)

#custom code
# combined_tv = torch.utils.data.ConcatDataset([image_dataset_train,image_dataset_val])
# image_dataloader_tv = DataLoader(combined_tv, batch_size=32,
#                         shuffle=False, num_workers=4)
for i,sample in enumerate(image_dataloader_train):
#     sample['image']=sample['image']#.cuda()
    print(i,sample['image'].shape,sample['img_path'],sample['Label'])
    if i>20: 
        break
# Out:
# (0, torch.Size([32, 3, 64, 64]), ['./data/trainClips/06624/1.jpg', './data/trainClips/03814/3.jpg', './data/trainClips/07010/3.jpg', './data/trainClips/06909/2.jpg', './data/trainClips/00542/1.jpg', './data/trainClips/07495/1.jpg', './data/trainClips/00121/1.jpg', './data/trainClips/00245/2.jpg', './data/trainClips/02179/2.jpg', './data/trainClips/02845/1.jpg', './data/trainClips/04136/1.jpg', './data/trainClips/00522/3.jpg', './data/trainClips/00291/3.jpg', './data/trainClips/02959/1.jpg', './data/trainClips/01181/3.jpg', './data/trainClips/01913/1.jpg', './data/trainClips/03610/2.jpg', './data/trainClips/07045/1.jpg', './data/trainClips/01009/1.jpg', './data/trainClips/00567/2.jpg', './data/trainClips/03847/1.jpg', './data/trainClips/04952/3.jpg', './data/trainClips/02010/2.jpg', './data/trainClips/05811/3.jpg', './data/trainClips/06788/2.jpg', './data/trainClips/03017/1.jpg', './data/trainClips/04375/3.jpg', './data/trainClips/04839/1.jpg', './data/trainClips/05400/3.jpg', './data/trainClips/04488/1.jpg', './data/trainClips/06670/2.jpg', './data/trainClips/00399/2.jpg'],
#  8
#  4
#  8
#  8
#  0
#  9
#  0
#  0
#  2
#  3
#  4
#  0
#  0
#  3
#  1
#  2
#  4
#  8
#  1
#  0
#  4
#  5
#  2
#  7
#  8
#  3
#  5
#  5
#  6
#  5
#  8
#  0
# [torch.DoubleTensor of size 32]
# )
# (1, torch.Size([32, 3, 64, 64]), ['./data/trainClips/06450/1.jpg', './data/trainClips/06605/3.jpg', './data/trainClips/01135/2.jpg', './data/trainClips/06655/1.jpg', './data/trainClips/04486/3.jpg', './data/trainClips/07446/3.jpg', './data/trainClips/01004/2.jpg', './data/trainClips/07031/2.jpg', './data/trainClips/00777/3.jpg', './data/trainClips/02922/2.jpg', './data/trainClips/02583/3.jpg', './data/trainClips/03417/3.jpg', './data/trainClips/06548/2.jpg', './data/trainClips/07148/1.jpg', './data/trainClips/06053/1.jpg', './data/trainClips/00281/3.jpg', './data/trainClips/06019/1.jpg', './data/trainClips/04076/2.jpg', './data/trainClips/02953/3.jpg', './data/trainClips/07718/2.jpg', './data/trainClips/03240/3.jpg', './data/trainClips/01017/1.jpg', './data/trainClips/00752/3.jpg', './data/trainClips/07098/3.jpg', './data/trainClips/02005/2.jpg', './data/trainClips/00760/3.jpg', './data/trainClips/02711/1.jpg', './data/trainClips/05765/1.jpg', './data/trainClips/02084/3.jpg', './data/trainClips/04806/1.jpg', './data/trainClips/02170/3.jpg', './data/trainClips/07540/2.jpg'],
#  7
#  8
#  1
#  8
#  5
#  9
#  1
#  8
#  0
#  3
#  2
#  3
#  8
#  9
#  7
#  0
#  7
#  4
#  3
#  9
#  3
#  1
#  0
#  8
#  2
#  0
#  3
#  7
#  2
#  5
#  2
#  9
# [torch.DoubleTensor of size 32]
# )
# (2, torch.Size([32, 3, 64, 64]), ['./data/trainClips/02852/3.jpg', './data/trainClips/06029/3.jpg', './data/trainClips/02743/1.jpg', './data/trainClips/03382/2.jpg', './data/trainClips/01502/3.jpg', './data/trainClips/04485/3.jpg', './data/trainClips/04948/1.jpg', './data/trainClips/06660/2.jpg', './data/trainClips/02988/1.jpg', './data/trainClips/07225/2.jpg', './data/trainClips/03013/1.jpg', './data/trainClips/03028/3.jpg', './data/trainClips/00886/3.jpg', './data/trainClips/05582/1.jpg', './data/trainClips/02766/3.jpg', './data/trainClips/00626/3.jpg', './data/trainClips/00483/3.jpg', './data/trainClips/03878/1.jpg', './data/trainClips/06736/3.jpg', './data/trainClips/02663/3.jpg', './data/trainClips/04991/2.jpg', './data/trainClips/04889/1.jpg', './data/trainClips/03241/1.jpg', './data/trainClips/03791/2.jpg', './data/trainClips/02528/2.jpg', './data/trainClips/05895/1.jpg', './data/trainClips/01734/3.jpg', './data/trainClips/01306/3.jpg', './data/trainClips/07101/1.jpg', './data/trainClips/00673/3.jpg', './data/trainClips/07213/1.jpg', './data/trainClips/00094/1.jpg'],
#  3
#  7
#  3
#  3
#  1
#  5
#  5
#  8
#  3
#  9
#  3
#  3
#  0
#  6
#  3
#  0
#  0
#  4
#  8
#  2
#  6
#  5
#  3
#  4
#  2
#  7
#  1
#  1
#  8
#  0
#  9
#  0
# [torch.DoubleTensor of size 32]
# )
# (3, torch.Size([32, 3, 64, 64]), ['./data/trainClips/05607/1.jpg', './data/trainClips/00234/1.jpg', './data/trainClips/03364/2.jpg', './data/trainClips/04464/2.jpg', './data/trainClips/05561/3.jpg', './data/trainClips/02416/1.jpg', './data/trainClips/02908/2.jpg', './data/trainClips/02849/3.jpg', './data/trainClips/07563/1.jpg', './data/trainClips/03604/2.jpg', './data/trainClips/04907/3.jpg', './data/trainClips/02646/3.jpg', './data/trainClips/06664/3.jpg', './data/trainClips/06405/1.jpg', './data/trainClips/07226/3.jpg', './data/trainClips/03076/2.jpg', './data/trainClips/01613/3.jpg', './data/trainClips/03926/1.jpg', './data/trainClips/02905/3.jpg', './data/trainClips/01434/3.jpg', './data/trainClips/00564/1.jpg', './data/trainClips/01151/2.jpg', './data/trainClips/06668/2.jpg', './data/trainClips/02331/1.jpg', './data/trainClips/07538/1.jpg', './data/trainClips/04664/2.jpg', './data/trainClips/03343/1.jpg', './data/trainClips/03391/2.jpg', './data/trainClips/02900/2.jpg', './data/trainClips/02623/2.jpg', './data/trainClips/00113/3.jpg', './data/trainClips/06219/2.jpg'],
#  6
#  0
#  3
#  5
#  6
#  2
#  3
#  3
#  9
#  4
#  5
#  2
#  8
#  7
#  9
#  3
#  1
#  4
#  3
#  1
#  0
#  1
#  8
#  2
#  9
#  5
#  3
#  3
#  3
#  2
#  0
#  7
# [torch.DoubleTensor of size 32]
# )
# (4, torch.Size([32, 3, 64, 64]), ['./data/trainClips/07446/2.jpg', './data/trainClips/07747/2.jpg', './data/trainClips/06927/3.jpg', './data/trainClips/00728/2.jpg', './data/trainClips/00084/3.jpg', './data/trainClips/07216/3.jpg', './data/trainClips/02214/2.jpg', './data/trainClips/04835/2.jpg', './data/trainClips/01097/3.jpg', './data/trainClips/05924/3.jpg', './data/trainClips/07358/2.jpg', './data/trainClips/02901/3.jpg', './data/trainClips/01123/2.jpg', './data/trainClips/02183/1.jpg', './data/trainClips/03435/2.jpg', './data/trainClips/00953/3.jpg', './data/trainClips/06335/2.jpg', './data/trainClips/04135/3.jpg', './data/trainClips/01435/1.jpg', './data/trainClips/01677/3.jpg', './data/trainClips/01567/1.jpg', './data/trainClips/03097/2.jpg', './data/trainClips/03690/1.jpg', './data/trainClips/04547/2.jpg', './data/trainClips/04930/2.jpg', './data/trainClips/04906/3.jpg', './data/trainClips/06649/3.jpg', './data/trainClips/01996/3.jpg', './data/trainClips/07088/3.jpg', './data/trainClips/03880/1.jpg', './data/trainClips/01994/3.jpg', './data/trainClips/05628/3.jpg'],
#  9
#  9
#  8
#  0
#  0
#  9
#  2
#  5
#  1
#  7
#  9
#  3
#  1
#  2
#  3
#  1
#  7
#  4
#  1
#  1
#  1
#  3
#  4
#  5
#  5
#  5
#  8
#  2
#  8
#  4
#  2
#  6
# [torch.DoubleTensor of size 32]
# )
# (5, torch.Size([32, 3, 64, 64]), ['./data/trainClips/04267/2.jpg', './data/trainClips/06547/2.jpg', './data/trainClips/06454/3.jpg', './data/trainClips/07483/2.jpg', './data/trainClips/05566/3.jpg', './data/trainClips/02044/2.jpg', './data/trainClips/04063/3.jpg', './data/trainClips/02692/2.jpg', './data/trainClips/05478/2.jpg', './data/trainClips/02887/2.jpg', './data/trainClips/06589/2.jpg', './data/trainClips/00610/3.jpg', './data/trainClips/00767/1.jpg', './data/trainClips/04532/2.jpg', './data/trainClips/04661/1.jpg', './data/trainClips/06315/3.jpg', './data/trainClips/02631/3.jpg', './data/trainClips/02899/2.jpg', './data/trainClips/04855/2.jpg', './data/trainClips/04993/2.jpg', './data/trainClips/01134/3.jpg', './data/trainClips/05295/2.jpg', './data/trainClips/07753/3.jpg', './data/trainClips/01318/3.jpg', './data/trainClips/06120/2.jpg', './data/trainClips/07302/1.jpg', './data/trainClips/05298/1.jpg', './data/trainClips/04929/2.jpg', './data/trainClips/06879/2.jpg', './data/trainClips/00109/2.jpg', './data/trainClips/02180/3.jpg', './data/trainClips/00371/1.jpg'],
#  5
#  8
#  7
#  9
#  6
#  2
#  4
#  3
#  6
#  3
#  8
#  0
#  0
#  5
#  5
#  7
#  2
#  3
#  5
#  6
#  1
#  6
#  9
#  1
#  7
#  9
#  6
#  5
#  8
#  0
#  2
#  0
# [torch.DoubleTensor of size 32]
# )
# (6, torch.Size([32, 3, 64, 64]), ['./data/trainClips/07588/3.jpg', './data/trainClips/04301/1.jpg', './data/trainClips/01527/2.jpg', './data/trainClips/00445/1.jpg', './data/trainClips/01980/1.jpg', './data/trainClips/00735/1.jpg', './data/trainClips/02910/2.jpg', './data/trainClips/05053/2.jpg', './data/trainClips/04630/2.jpg', './data/trainClips/03953/2.jpg', './data/trainClips/05346/1.jpg', './data/trainClips/03797/2.jpg', './data/trainClips/05241/2.jpg', './data/trainClips/02805/3.jpg', './data/trainClips/02514/2.jpg', './data/trainClips/05361/1.jpg', './data/trainClips/04964/2.jpg', './data/trainClips/00718/2.jpg', './data/trainClips/06284/2.jpg', './data/trainClips/06642/2.jpg', './data/trainClips/06184/2.jpg', './data/trainClips/00420/1.jpg', './data/trainClips/03582/1.jpg', './data/trainClips/03723/1.jpg', './data/trainClips/05667/1.jpg', './data/trainClips/05312/2.jpg', './data/trainClips/05128/2.jpg', './data/trainClips/05506/2.jpg', './data/trainClips/02133/3.jpg', './data/trainClips/04733/1.jpg', './data/trainClips/00045/1.jpg', './data/trainClips/01114/3.jpg'],
#  9
#  5
#  1
#  0
#  2
#  0
#  3
#  6
#  5
#  4
#  6
#  4
#  6
#  3
#  2
#  6
#  5
#  0
#  7
#  8
#  7
#  0
#  4
#  4
#  7
#  6
#  6
#  6
#  2
#  5
#  0
#  1
# [torch.DoubleTensor of size 32]
# )
# (7, torch.Size([32, 3, 64, 64]), ['./data/trainClips/00320/1.jpg', './data/trainClips/00944/2.jpg', './data/trainClips/05038/1.jpg', './data/trainClips/03159/1.jpg', './data/trainClips/07274/1.jpg', './data/trainClips/07211/3.jpg', './data/trainClips/06592/2.jpg', './data/trainClips/02325/1.jpg', './data/trainClips/06394/1.jpg', './data/trainClips/00334/3.jpg', './data/trainClips/00548/2.jpg', './data/trainClips/00979/3.jpg', './data/trainClips/01597/3.jpg', './data/trainClips/02591/2.jpg', './data/trainClips/07208/2.jpg', './data/trainClips/03355/1.jpg', './data/trainClips/04545/2.jpg', './data/trainClips/04465/2.jpg', './data/trainClips/07740/1.jpg', './data/trainClips/00227/1.jpg', './data/trainClips/01366/1.jpg', './data/trainClips/01416/2.jpg', './data/trainClips/06148/2.jpg', './data/trainClips/04798/2.jpg', './data/trainClips/04616/2.jpg', './data/trainClips/00473/2.jpg', './data/trainClips/03513/3.jpg', './data/trainClips/02388/3.jpg', './data/trainClips/02356/1.jpg', './data/trainClips/03014/2.jpg', './data/trainClips/03864/3.jpg', './data/trainClips/05511/2.jpg'],
#  0
#  1
#  6
#  3
#  9
#  9
#  8
#  2
#  7
#  0
#  0
#  1
#  1
#  2
#  9
#  3
#  5
#  5
#  9
#  0
#  1
#  1
#  7
#  5
#  5
#  0
#  3
#  2
#  2
#  3
#  4
#  6
# [torch.DoubleTensor of size 32]
# )
# (8, torch.Size([32, 3, 64, 64]), ['./data/trainClips/01765/3.jpg', './data/trainClips/07365/1.jpg', './data/trainClips/03559/2.jpg', './data/trainClips/02783/2.jpg', './data/trainClips/01844/2.jpg', './data/trainClips/05443/3.jpg', './data/trainClips/03189/1.jpg', './data/trainClips/02645/3.jpg', './data/trainClips/01765/1.jpg', './data/trainClips/07320/1.jpg', './data/trainClips/05033/1.jpg', './data/trainClips/07717/1.jpg', './data/trainClips/07386/2.jpg', './data/trainClips/04334/3.jpg', './data/trainClips/01023/2.jpg', './data/trainClips/01337/1.jpg', './data/trainClips/04702/1.jpg', './data/trainClips/01260/1.jpg', './data/trainClips/02246/1.jpg', './data/trainClips/02003/3.jpg', './data/trainClips/05593/3.jpg', './data/trainClips/07256/2.jpg', './data/trainClips/03315/1.jpg', './data/trainClips/03245/1.jpg', './data/trainClips/02145/3.jpg', './data/trainClips/01470/3.jpg', './data/trainClips/02354/1.jpg', './data/trainClips/00593/1.jpg', './data/trainClips/01058/1.jpg', './data/trainClips/04509/2.jpg', './data/trainClips/07692/2.jpg', './data/trainClips/02426/3.jpg'],
#  1
#  9
#  4
#  3
#  2
#  6
#  3
#  2
#  1
#  9
#  6
#  9
#  9
#  5
#  1
#  1
#  5
#  1
#  2
#  2
#  6
#  9
#  3
#  3
#  2
#  1
#  2
#  0
#  1
#  5
#  9
#  2
# [torch.DoubleTensor of size 32]
# )
# (9, torch.Size([32, 3, 64, 64]), ['./data/trainClips/06998/1.jpg', './data/trainClips/01948/3.jpg', './data/trainClips/04551/1.jpg', './data/trainClips/05859/3.jpg', './data/trainClips/05995/2.jpg', './data/trainClips/03474/3.jpg', './data/trainClips/01265/1.jpg', './data/trainClips/00806/2.jpg', './data/trainClips/06276/3.jpg', './data/trainClips/07150/2.jpg', './data/trainClips/03869/2.jpg', './data/trainClips/07470/3.jpg', './data/trainClips/02173/1.jpg', './data/trainClips/05443/2.jpg', './data/trainClips/07569/1.jpg', './data/trainClips/05968/3.jpg', './data/trainClips/07471/2.jpg', './data/trainClips/02859/3.jpg', './data/trainClips/07524/1.jpg', './data/trainClips/00376/1.jpg', './data/trainClips/00464/2.jpg', './data/trainClips/03465/2.jpg', './data/trainClips/05026/2.jpg', './data/trainClips/04598/3.jpg', './data/trainClips/05354/3.jpg', './data/trainClips/04707/1.jpg', './data/trainClips/01102/3.jpg', './data/trainClips/01433/3.jpg', './data/trainClips/06548/3.jpg', './data/trainClips/00395/3.jpg', './data/trainClips/05397/2.jpg', './data/trainClips/05634/3.jpg'],
#  8
#  2
#  5
#  7
#  7
#  3
#  1
#  0
#  7
#  9
#  4
#  9
#  2
#  6
#  9
#  7
#  9
#  3
#  9
#  0
#  0
#  3
#  6
#  5
#  6
#  5
#  1
#  1
#  8
#  0
#  6
#  7
# [torch.DoubleTensor of size 32]
# )
# (10, torch.Size([32, 3, 64, 64]), ['./data/trainClips/04578/3.jpg', './data/trainClips/07646/3.jpg', './data/trainClips/00715/3.jpg', './data/trainClips/05620/2.jpg', './data/trainClips/07486/3.jpg', './data/trainClips/02714/1.jpg', './data/trainClips/06903/3.jpg', './data/trainClips/06300/2.jpg', './data/trainClips/04511/3.jpg', './data/trainClips/06355/2.jpg', './data/trainClips/02870/2.jpg', './data/trainClips/03732/3.jpg', './data/trainClips/02464/3.jpg', './data/trainClips/06453/1.jpg', './data/trainClips/00770/3.jpg', './data/trainClips/01792/2.jpg', './data/trainClips/06226/2.jpg', './data/trainClips/06675/3.jpg', './data/trainClips/04403/3.jpg', './data/trainClips/02451/1.jpg', './data/trainClips/03131/1.jpg', './data/trainClips/06192/2.jpg', './data/trainClips/06580/1.jpg', './data/trainClips/06925/3.jpg', './data/trainClips/04511/1.jpg', './data/trainClips/05645/2.jpg', './data/trainClips/02106/3.jpg', './data/trainClips/04276/3.jpg', './data/trainClips/01916/2.jpg', './data/trainClips/04553/1.jpg', './data/trainClips/06582/2.jpg', './data/trainClips/06353/2.jpg'],
#  5
#  9
#  0
#  6
#  9
#  3
#  8
#  7
#  5
#  7
#  3
#  4
#  2
#  7
#  0
#  1
#  7
#  8
#  5
#  2
#  3
#  7
#  8
#  8
#  5
#  7
#  2
#  5
#  2
#  5
#  8
#  7
# [torch.DoubleTensor of size 32]
# )
# (11, torch.Size([32, 3, 64, 64]), ['./data/trainClips/03206/3.jpg', './data/trainClips/06957/2.jpg', './data/trainClips/04861/1.jpg', './data/trainClips/00173/3.jpg', './data/trainClips/06018/2.jpg', './data/trainClips/01600/1.jpg', './data/trainClips/02110/3.jpg', './data/trainClips/05791/3.jpg', './data/trainClips/03462/3.jpg', './data/trainClips/01189/1.jpg', './data/trainClips/01655/2.jpg', './data/trainClips/00917/3.jpg', './data/trainClips/06470/3.jpg', './data/trainClips/07612/1.jpg', './data/trainClips/00223/1.jpg', './data/trainClips/06486/3.jpg', './data/trainClips/05072/3.jpg', './data/trainClips/02029/1.jpg', './data/trainClips/06753/1.jpg', './data/trainClips/06001/3.jpg', './data/trainClips/02114/3.jpg', './data/trainClips/07562/2.jpg', './data/trainClips/03120/3.jpg', './data/trainClips/02595/3.jpg', './data/trainClips/03759/2.jpg', './data/trainClips/02572/2.jpg', './data/trainClips/02980/1.jpg', './data/trainClips/04099/2.jpg', './data/trainClips/07355/2.jpg', './data/trainClips/02151/3.jpg', './data/trainClips/01249/1.jpg', './data/trainClips/04789/1.jpg'],
#  3
#  8
#  5
#  0
#  7
#  1
#  2
#  7
#  3
#  1
#  1
#  1
#  7
#  9
#  0
#  8
#  6
#  2
#  8
#  7
#  2
#  9
#  3
#  2
#  4
#  2
#  3
#  4
#  9
#  2
#  1
#  5
# [torch.DoubleTensor of size 32]
# )
# (12, torch.Size([32, 3, 64, 64]), ['./data/trainClips/00429/2.jpg', './data/trainClips/00117/2.jpg', './data/trainClips/00229/2.jpg', './data/trainClips/02728/3.jpg', './data/trainClips/02526/2.jpg', './data/trainClips/01319/1.jpg', './data/trainClips/06487/1.jpg', './data/trainClips/05932/2.jpg', './data/trainClips/04242/3.jpg', './data/trainClips/01272/1.jpg', './data/trainClips/02777/3.jpg', './data/trainClips/07516/1.jpg', './data/trainClips/05088/2.jpg', './data/trainClips/07611/2.jpg', './data/trainClips/05979/3.jpg', './data/trainClips/04399/3.jpg', './data/trainClips/04393/2.jpg', './data/trainClips/06692/3.jpg', './data/trainClips/01716/1.jpg', './data/trainClips/05327/3.jpg', './data/trainClips/04274/1.jpg', './data/trainClips/04688/1.jpg', './data/trainClips/03406/2.jpg', './data/trainClips/04922/3.jpg', './data/trainClips/00853/1.jpg', './data/trainClips/04706/1.jpg', './data/trainClips/02604/3.jpg', './data/trainClips/07239/1.jpg', './data/trainClips/06865/3.jpg', './data/trainClips/01147/3.jpg', './data/trainClips/05145/2.jpg', './data/trainClips/03525/3.jpg'],
#  0
#  0
#  0
#  3
#  2
#  1
#  8
#  7
#  5
#  1
#  3
#  9
#  6
#  9
#  7
#  5
#  5
#  8
#  1
#  6
#  5
#  5
#  3
#  5
#  0
#  5
#  2
#  9
#  8
#  1
#  6
#  4
# [torch.DoubleTensor of size 32]
# )
# (13, torch.Size([32, 3, 64, 64]), ['./data/trainClips/00648/1.jpg', './data/trainClips/06165/2.jpg', './data/trainClips/03934/2.jpg', './data/trainClips/03228/1.jpg', './data/trainClips/03675/3.jpg', './data/trainClips/07222/3.jpg', './data/trainClips/07038/3.jpg', './data/trainClips/04515/1.jpg', './data/trainClips/05982/2.jpg', './data/trainClips/01367/2.jpg', './data/trainClips/03451/3.jpg', './data/trainClips/02742/1.jpg', './data/trainClips/00668/3.jpg', './data/trainClips/00576/1.jpg', './data/trainClips/01981/3.jpg', './data/trainClips/00334/1.jpg', './data/trainClips/06201/2.jpg', './data/trainClips/03518/2.jpg', './data/trainClips/02705/1.jpg', './data/trainClips/06624/2.jpg', './data/trainClips/07370/2.jpg', './data/trainClips/04527/2.jpg', './data/trainClips/02551/3.jpg', './data/trainClips/02457/3.jpg', './data/trainClips/03321/2.jpg', './data/trainClips/01958/3.jpg', './data/trainClips/04967/3.jpg', './data/trainClips/05973/3.jpg', './data/trainClips/07065/2.jpg', './data/trainClips/00479/1.jpg', './data/trainClips/01679/1.jpg', './data/trainClips/05194/1.jpg'],
#  0
#  7
#  4
#  3
#  4
#  9
#  8
#  5
#  7
#  1
#  3
#  3
#  0
#  0
#  2
#  0
#  7
#  3
#  3
#  8
#  9
#  5
#  2
#  2
#  3
#  2
#  5
#  7
#  8
#  0
#  1
#  6
# [torch.DoubleTensor of size 32]
# )
# (14, torch.Size([32, 3, 64, 64]), ['./data/trainClips/05020/1.jpg', './data/trainClips/01339/2.jpg', './data/trainClips/06083/1.jpg', './data/trainClips/06832/2.jpg', './data/trainClips/01373/1.jpg', './data/trainClips/04278/1.jpg', './data/trainClips/01808/3.jpg', './data/trainClips/07111/2.jpg', './data/trainClips/01655/3.jpg', './data/trainClips/05343/1.jpg', './data/trainClips/00642/2.jpg', './data/trainClips/01506/1.jpg', './data/trainClips/01350/2.jpg', './data/trainClips/00219/2.jpg', './data/trainClips/06227/1.jpg', './data/trainClips/07115/3.jpg', './data/trainClips/04422/2.jpg', './data/trainClips/03571/2.jpg', './data/trainClips/05650/1.jpg', './data/trainClips/01368/3.jpg', './data/trainClips/02405/2.jpg', './data/trainClips/04600/1.jpg', './data/trainClips/03142/2.jpg', './data/trainClips/00744/3.jpg', './data/trainClips/06900/2.jpg', './data/trainClips/00652/1.jpg', './data/trainClips/07317/3.jpg', './data/trainClips/06787/2.jpg', './data/trainClips/07126/2.jpg', './data/trainClips/04376/2.jpg', './data/trainClips/05736/1.jpg', './data/trainClips/05922/1.jpg'],
#  6
#  1
#  7
#  8
#  1
#  5
#  1
#  8
#  1
#  6
#  0
#  1
#  1
#  0
#  7
#  8
#  5
#  4
#  7
#  1
#  2
#  5
#  3
#  0
#  8
#  0
#  9
#  8
#  8
#  5
#  7
#  7
# [torch.DoubleTensor of size 32]
# )
# (15, torch.Size([32, 3, 64, 64]), ['./data/trainClips/03003/1.jpg', './data/trainClips/07611/1.jpg', './data/trainClips/04951/1.jpg', './data/trainClips/03480/1.jpg', './data/trainClips/06211/3.jpg', './data/trainClips/00490/2.jpg', './data/trainClips/02083/3.jpg', './data/trainClips/03249/2.jpg', './data/trainClips/00791/2.jpg', './data/trainClips/04740/1.jpg', './data/trainClips/06878/1.jpg', './data/trainClips/02058/2.jpg', './data/trainClips/00396/1.jpg', './data/trainClips/00346/3.jpg', './data/trainClips/05711/2.jpg', './data/trainClips/03992/3.jpg', './data/trainClips/03385/1.jpg', './data/trainClips/01777/2.jpg', './data/trainClips/05545/2.jpg', './data/trainClips/05752/1.jpg', './data/trainClips/07324/2.jpg', './data/trainClips/06956/2.jpg', './data/trainClips/06994/1.jpg', './data/trainClips/02637/3.jpg', './data/trainClips/04809/1.jpg', './data/trainClips/04067/3.jpg', './data/trainClips/04051/2.jpg', './data/trainClips/05875/1.jpg', './data/trainClips/07324/1.jpg', './data/trainClips/01995/2.jpg', './data/trainClips/05456/3.jpg', './data/trainClips/03166/3.jpg'],
#  3
#  9
#  5
#  3
#  7
#  0
#  2
#  3
#  0
#  5
#  8
#  2
#  0
#  0
#  7
#  4
#  3
#  1
#  6
#  7
#  9
#  8
#  8
#  2
#  5
#  4
#  4
#  7
#  9
#  2
#  6
#  3
# [torch.DoubleTensor of size 32]
# )
# (16, torch.Size([32, 3, 64, 64]), ['./data/trainClips/03756/3.jpg', './data/trainClips/06767/1.jpg', './data/trainClips/02195/3.jpg', './data/trainClips/05515/3.jpg', './data/trainClips/06423/2.jpg', './data/trainClips/05833/2.jpg', './data/trainClips/06562/1.jpg', './data/trainClips/00604/1.jpg', './data/trainClips/04591/1.jpg', './data/trainClips/03649/3.jpg', './data/trainClips/00452/2.jpg', './data/trainClips/07163/2.jpg', './data/trainClips/04603/3.jpg', './data/trainClips/07653/2.jpg', './data/trainClips/05933/1.jpg', './data/trainClips/03838/3.jpg', './data/trainClips/03229/1.jpg', './data/trainClips/01803/1.jpg', './data/trainClips/04253/3.jpg', './data/trainClips/05436/1.jpg', './data/trainClips/00472/2.jpg', './data/trainClips/00694/3.jpg', './data/trainClips/01437/2.jpg', './data/trainClips/05798/1.jpg', './data/trainClips/06657/1.jpg', './data/trainClips/01756/3.jpg', './data/trainClips/02597/2.jpg', './data/trainClips/03466/2.jpg', './data/trainClips/03801/2.jpg', './data/trainClips/00418/1.jpg', './data/trainClips/06201/1.jpg', './data/trainClips/03068/3.jpg'],
#  4
#  8
#  2
#  6
#  7
#  7
#  8
#  0
#  5
#  4
#  0
#  9
#  5
#  9
#  7
#  4
#  3
#  1
#  5
#  6
#  0
#  0
#  1
#  7
#  8
#  1
#  2
#  3
#  4
#  0
#  7
#  3
# [torch.DoubleTensor of size 32]
# )
# (17, torch.Size([32, 3, 64, 64]), ['./data/trainClips/00839/1.jpg', './data/trainClips/07433/2.jpg', './data/trainClips/03024/1.jpg', './data/trainClips/02668/2.jpg', './data/trainClips/02849/2.jpg', './data/trainClips/06362/2.jpg', './data/trainClips/02181/2.jpg', './data/trainClips/02241/3.jpg', './data/trainClips/03187/3.jpg', './data/trainClips/02659/1.jpg', './data/trainClips/03857/3.jpg', './data/trainClips/01972/2.jpg', './data/trainClips/00575/1.jpg', './data/trainClips/03582/3.jpg', './data/trainClips/02745/2.jpg', './data/trainClips/02205/1.jpg', './data/trainClips/01646/3.jpg', './data/trainClips/02168/1.jpg', './data/trainClips/00230/3.jpg', './data/trainClips/00566/2.jpg', './data/trainClips/03232/1.jpg', './data/trainClips/00814/2.jpg', './data/trainClips/02516/1.jpg', './data/trainClips/00841/3.jpg', './data/trainClips/03113/3.jpg', './data/trainClips/06599/3.jpg', './data/trainClips/06349/3.jpg', './data/trainClips/07051/3.jpg', './data/trainClips/04713/2.jpg', './data/trainClips/06353/3.jpg', './data/trainClips/00361/2.jpg', './data/trainClips/06242/1.jpg'],
#  0
#  9
#  3
#  2
#  3
#  7
#  2
#  2
#  3
#  2
#  4
#  2
#  0
#  4
#  3
#  2
#  1
#  2
#  0
#  0
#  3
#  0
#  2
#  0
#  3
#  8
#  7
#  8
#  5
#  7
#  0
#  7
# [torch.DoubleTensor of size 32]
# )
# (18, torch.Size([32, 3, 64, 64]), ['./data/trainClips/05137/2.jpg', './data/trainClips/06077/1.jpg', './data/trainClips/05920/2.jpg', './data/trainClips/06989/1.jpg', './data/trainClips/03155/2.jpg', './data/trainClips/03741/3.jpg', './data/trainClips/01042/1.jpg', './data/trainClips/01732/2.jpg', './data/trainClips/01896/2.jpg', './data/trainClips/05497/2.jpg', './data/trainClips/05464/1.jpg', './data/trainClips/02223/2.jpg', './data/trainClips/02385/2.jpg', './data/trainClips/03585/2.jpg', './data/trainClips/01783/3.jpg', './data/trainClips/04509/3.jpg', './data/trainClips/00215/3.jpg', './data/trainClips/04038/3.jpg', './data/trainClips/02976/1.jpg', './data/trainClips/02933/2.jpg', './data/trainClips/02210/1.jpg', './data/trainClips/05017/3.jpg', './data/trainClips/07333/3.jpg', './data/trainClips/00251/3.jpg', './data/trainClips/00811/2.jpg', './data/trainClips/02879/2.jpg', './data/trainClips/05851/2.jpg', './data/trainClips/07230/2.jpg', './data/trainClips/06244/3.jpg', './data/trainClips/00719/1.jpg', './data/trainClips/03348/3.jpg', './data/trainClips/04241/1.jpg'],
#  6
#  7
#  7
#  8
#  3
#  4
#  1
#  1
#  2
#  6
#  6
#  2
#  2
#  4
#  1
#  5
#  0
#  4
#  3
#  3
#  2
#  6
#  9
#  0
#  0
#  3
#  7
#  9
#  7
#  0
#  3
#  5
# [torch.DoubleTensor of size 32]
# )
# (19, torch.Size([32, 3, 64, 64]), ['./data/trainClips/02993/3.jpg', './data/trainClips/01464/1.jpg', './data/trainClips/01384/1.jpg', './data/trainClips/01833/3.jpg', './data/trainClips/03737/3.jpg', './data/trainClips/00998/3.jpg', './data/trainClips/06254/2.jpg', './data/trainClips/04306/1.jpg', './data/trainClips/05080/2.jpg', './data/trainClips/03438/1.jpg', './data/trainClips/05865/1.jpg', './data/trainClips/05850/1.jpg', './data/trainClips/06858/2.jpg', './data/trainClips/01640/3.jpg', './data/trainClips/07674/2.jpg', './data/trainClips/00354/1.jpg', './data/trainClips/04997/3.jpg', './data/trainClips/05373/2.jpg', './data/trainClips/06961/2.jpg', './data/trainClips/02333/1.jpg', './data/trainClips/00468/3.jpg', './data/trainClips/03244/2.jpg', './data/trainClips/03753/2.jpg', './data/trainClips/01832/3.jpg', './data/trainClips/02057/2.jpg', './data/trainClips/05982/3.jpg', './data/trainClips/00120/1.jpg', './data/trainClips/07471/1.jpg', './data/trainClips/07442/1.jpg', './data/trainClips/07567/2.jpg', './data/trainClips/04416/1.jpg', './data/trainClips/01544/2.jpg'],
#  3
#  1
#  1
#  2
#  4
#  1
#  7
#  5
#  6
#  3
#  7
#  7
#  8
#  1
#  9
#  0
#  6
#  6
#  8
#  2
#  0
#  3
#  4
#  2
#  2
#  7
#  0
#  9
#  9
#  9
#  5
#  1
# [torch.DoubleTensor of size 32]
# )
# (20, torch.Size([32, 3, 64, 64]), ['./data/trainClips/02357/1.jpg', './data/trainClips/02006/3.jpg', './data/trainClips/03170/1.jpg', './data/trainClips/00339/3.jpg', './data/trainClips/03678/3.jpg', './data/trainClips/01002/3.jpg', './data/trainClips/00105/3.jpg', './data/trainClips/05035/1.jpg', './data/trainClips/06036/2.jpg', './data/trainClips/00505/1.jpg', './data/trainClips/02751/2.jpg', './data/trainClips/03790/2.jpg', './data/trainClips/00993/2.jpg', './data/trainClips/05480/1.jpg', './data/trainClips/06387/1.jpg', './data/trainClips/02336/2.jpg', './data/trainClips/00299/1.jpg', './data/trainClips/07536/2.jpg', './data/trainClips/01294/2.jpg', './data/trainClips/06896/3.jpg', './data/trainClips/06710/1.jpg', './data/trainClips/05516/1.jpg', './data/trainClips/02840/3.jpg', './data/trainClips/01667/3.jpg', './data/trainClips/07206/3.jpg', './data/trainClips/00962/3.jpg', './data/trainClips/03152/3.jpg', './data/trainClips/01001/3.jpg', './data/trainClips/04988/3.jpg', './data/trainClips/00120/3.jpg', './data/trainClips/02773/3.jpg', './data/trainClips/03977/2.jpg'],
#  2
#  2
#  3
#  0
#  4
#  1
#  0
#  6
#  7
#  0
#  3
#  4
#  1
#  6
#  7
#  2
#  0
#  9
#  1
#  8
#  8
#  6
#  3
#  1
#  9
#  1
#  3
#  1
#  6
#  0
#  3
#  4
# [torch.DoubleTensor of size 32]
# )
# (21, torch.Size([32, 3, 64, 64]), ['./data/trainClips/00392/2.jpg', './data/trainClips/00923/3.jpg', './data/trainClips/00372/3.jpg', './data/trainClips/03223/2.jpg', './data/trainClips/04756/1.jpg', './data/trainClips/07463/3.jpg', './data/trainClips/06892/3.jpg', './data/trainClips/07746/3.jpg', './data/trainClips/00559/2.jpg', './data/trainClips/00822/3.jpg', './data/trainClips/02808/1.jpg', './data/trainClips/04434/1.jpg', './data/trainClips/00994/3.jpg', './data/trainClips/05027/1.jpg', './data/trainClips/05739/1.jpg', './data/trainClips/03349/1.jpg', './data/trainClips/00941/3.jpg', './data/trainClips/05406/2.jpg', './data/trainClips/04387/1.jpg', './data/trainClips/00182/3.jpg', './data/trainClips/01164/1.jpg', './data/trainClips/03132/1.jpg', './data/trainClips/04889/2.jpg', './data/trainClips/03005/2.jpg', './data/trainClips/05832/3.jpg', './data/trainClips/00534/3.jpg', './data/trainClips/07037/2.jpg', './data/trainClips/00158/1.jpg', './data/trainClips/06687/1.jpg', './data/trainClips/02973/2.jpg', './data/trainClips/03379/1.jpg', './data/trainClips/01380/2.jpg'],
#  0
#  1
#  0
#  3
#  5
#  9
#  8
#  9
#  0
#  0
#  3
#  5
#  1
#  6
#  7
#  3
#  1
#  6
#  5
#  0
#  1
#  3
#  5
#  3
#  7
#  0
#  8
#  0
#  8
#  3
#  3
#  1
# [torch.DoubleTensor of size 32]
# )

# %%
dtype = torch.FloatTensor # the CPU datatype
# Constant to control how frequently we print train loss
print_every = 100
# This is a little utility that we'll use to reset the model
# if we want to re-initialize all our parameters
def reset(m):
    if hasattr(m, 'reset_parameters'):
        m.reset_parameters()

# %% [markdown]
# ## Example Model
#
# ### Some assorted tidbits
#
# Let's start by looking at a simple model. First, note that PyTorch operates on Tensors, which are n-dimensional arrays functionally analogous to numpy's ndarrays, with the additional feature that they can be used for computations on GPUs.
#
# We'll provide you with a Flatten function, which we explain here. Remember that our image data (and more relevantly, our intermediate feature maps) are initially N x C x H x W, where:
# * N is the number of datapoints
# * C is the number of image channels.
# * H is the height of the intermediate feature map in pixels
# * W is the height of the intermediate feature map in pixels
#
# This is the right way to represent the data when we are doing something like a 2D convolution, that needs spatial understanding of where the intermediate features are relative to each other. When we input  data into fully connected affine layers, however, we want each datapoint to be represented by a single vector -- it's no longer useful to segregate the different channels, rows, and columns of the data. So, we use a "Flatten" operation to collapse the C x H x W values per representation into a single long vector. The Flatten function below first reads in the N, C, H, and W values from a given batch of data, and then returns a "view" of that data. "View" is analogous to numpy's "reshape" method: it reshapes x's dimensions to be N x ??, where ?? is allowed to be anything (in this case, it will be C x H x W, but we don't need to specify that explicitly).

# %%
class Flatten(nn.Module):

    def forward(self, x):
        N, C, H, W = x.size() # read in N, C, H, W
        return x.view(N, -1)  # "flatten" the C * H * W values into a single vector per image

# %% [markdown]
# ### The example model itself
#
# The first step to training your own model is defining its architecture.
#
# Here's an example of a convolutional neural network defined in PyTorch -- try to understand what each line is doing, remembering that each layer is composed upon the previous layer. We haven't trained anything yet - that'll come next - for now, we want you to understand how everything gets set up.  nn.Sequential is a container which applies each layer
# one after the other.
#
# In this example, you see 2D convolutional layers (Conv2d), ReLU activations, and fully-connected layers (Linear). You also see the Cross-Entropy loss function, and the Adam optimizer being used.
#
# Make sure you understand why the parameters of the Linear layer are 10092 and 10.

# %%
# Here's where we define the architecture of the model... 
simple_model = nn.Sequential(
                nn.Conv2d(3, 32, kernel_size=7, stride=2),
                nn.ReLU(inplace=True),
                Flatten(), # see above for explanation
                nn.Linear(10092, 10), # affine layer
              )

# Set the type of all data in this model to be FloatTensor 
simple_model.type(dtype)

loss_fn = nn.CrossEntropyLoss().type(dtype)
optimizer = optim.Adam(simple_model.parameters(), lr=1e-2) # lr sets the learning rate of the optimizer

# %% [markdown]
# PyTorch supports many other layer types, loss functions, and optimizers - you will experiment with these next. Here's the official API documentation for these (if any of the parameters used above were unclear, this resource will also be helpful).
#
# * Layers: http://pytorch.org/docs/nn.html
# * Activations: http://pytorch.org/docs/nn.html#non-linear-activations
# * Loss functions: http://pytorch.org/docs/nn.html#loss-functions
# * Optimizers: http://pytorch.org/docs/optim.html#algorithms

# %% [markdown]
# ## Training a specific model
#
# In this section, we're going to specify a model for you to construct. The goal here isn't to get good performance (that'll be next), but instead to get comfortable with understanding the PyTorch documentation and configuring your own model.
#
# Using the code provided above as guidance, and using the following PyTorch documentation, specify a model with the following architecture:
#
# * 7x7 Convolutional Layer with 8 filters and stride of 1
# * ReLU Activation Layer
# * 2x2 Max Pooling layer with a stride of 2
# * 7x7 Convolutional Layer with 16 filters and stride of 1
# * ReLU Activation Layer
# * 2x2 Max Pooling layer with a stride of 2
# * Flatten the feature map
# * ReLU Activation Layer
# * Affine layer to map input units to 10 outputs, you need to figure out the input size here.

# %% [markdown]
# To make sure you're doing the right thing, use the following tool to check the dimensionality of your output (it should be 32 x 10, since our batches have size 32 and the output of the final affine layer should be 10, corresponding to our 10 classes):

# %%
    #########1st To Do  (10 points)###################
   
    ####################################


fixed_model_base = nn.Sequential( 
                nn.Conv2d(3,8,kernel_size=(7,7), stride=1),
                nn.ReLU(inplace=True),
                nn.MaxPool2d((2,2),2),
                nn.Conv2d(8, 16,kernel_size=(7,7), stride=1),
                nn.ReLU(inplace=True),
                nn.MaxPool2d((2,2),2),
                Flatten(), 
                nn.ReLU(),
                nn.Linear(1936, 10), # affine layer
            )
fixed_model = fixed_model_base.type(dtype)

# %%
## Now we're going to feed a random batch into the model you defined and make sure the output is the right size
x = torch.randn(32, 3, 64, 64).type(dtype)
x_var = Variable(x.type(dtype)) # Construct a PyTorch Variable out of your input data
ans = fixed_model(x_var)        # Feed it through the model! 

# Check to make sure what comes out of your model
# is the right dimensionality... this should be True
# if you've done everything correctly
print(np.array(ans.size()))
np.array_equal(np.array(ans.size()), np.array([32, 10]))
# Out:
# [32 10]
# True

# %% [markdown]
# ### Train the model.
#
# Now that you've seen how to define a model and do a single forward pass of some data through it, let's  walk through how you'd actually train one whole epoch over your training data (using the fixed_model_base we provided above).
#
# Make sure you understand how each PyTorch function used below corresponds to what you implemented in your custom neural network implementation.
#
# Note that because we are not resetting the weights anywhere below, if you run the cell multiple times, you are effectively training multiple epochs (so your performance should improve).
#
# First, set up an RMSprop optimizer (using a 1e-4 learning rate) and a cross-entropy loss function:

# %%
################ 2nd To Do  (5 points)##################
optimizer = torch.optim.RMSprop(fixed_model.parameters(), lr=1e-4)
loss_fn = nn.CrossEntropyLoss()

# %%
# This sets the model in "training" mode. 
# This is relevant for some layers that may have different behavior
# in training mode vs testing mode, such as Dropout and BatchNorm. 
fixed_model.train()

# Load one batch at a time.
for t, sample in enumerate(image_dataloader_train):
    x_var = Variable(sample['image'])
    #print(type(x_var.data))
    #print(x_var.shape)
    y_var = Variable(sample['Label']).long()

    # This is the forward pass: predict the scores for each class, for each x in the batch.
    scores = fixed_model(x_var)
    
    # Use the correct y values and the predicted y values to compute the loss.
    loss = loss_fn(scores, y_var)
    
    if (t + 1) % print_every == 0:
        print('t = %d, loss = %.4f' % (t + 1, loss.data[0]))

    # Zero out all of the gradients for the variables which the optimizer will update.
    optimizer.zero_grad()
    
    # This is the backwards pass: compute the gradient of the loss with respect to each 
    # parameter of the model.
    loss.backward()
    
    # Actually update the parameters of the model using the gradients computed by the backwards pass.
    optimizer.step()
# Out:
# t = 100, loss = 1.9630
# t = 200, loss = 1.6624
# t = 300, loss = 1.8599
# t = 400, loss = 1.6015
# t = 500, loss = 1.2223
# t = 600, loss = 1.3336
# t = 700, loss = 1.2920

# %% [markdown]
# Now you've seen how the training process works in PyTorch. To save you writing boilerplate code, we're providing the following helper functions to help you train for multiple epochs and check the accuracy of your model:

# %%
def train(model, loss_fn, optimizer, dataloader, num_epochs = 1):
    for epoch in range(num_epochs):
        print('Starting epoch %d / %d' % (epoch + 1, num_epochs))
        model.train()
        for t, sample in enumerate(dataloader):
            x_var = Variable(sample['image'])
            y_var = Variable(sample['Label'].long())

            scores = model(x_var)
            
            loss = loss_fn(scores, y_var)
            if (t + 1) % print_every == 0:
                print('t = %d, loss = %.4f' % (t + 1, loss.data[0]))

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

def check_accuracy(model, loader):
    '''
    if loader.dataset.train:
        print('Checking accuracy on validation set')
    else:
        print('Checking accuracy on test set')  
    '''
    num_correct = 0
    num_samples = 0
    model.eval() # Put the model in test mode (the opposite of model.train(), essentially)
    for t, sample in enumerate(loader):
        x_var = Variable(sample['image'])
        y_var = sample['Label']
        #y_var=y_var.cpu()
        scores = model(x_var)
        _, preds = scores.data.max(1)#scores.data.cpu().max(1)
        #print(preds)
        #print(y_var)
        num_correct += (preds.numpy() == y_var.numpy()).sum()
        num_samples += preds.size(0)
    acc = float(num_correct) / num_samples
    print('Got %d / %d correct (%.2f)' % (num_correct, num_samples, 100 * acc))

# %% [markdown]
# ### Check the accuracy of the model.
#
# Let's see the train and check_accuracy code in action -- feel free to use these methods when evaluating the models you develop below.
#
# You should get a training loss of around 1.0-1.2, and a validation accuracy of around 50-60%. As mentioned above, if you re-run the cells, you'll be training more epochs, so your performance will improve past these numbers.
#
# But don't worry about getting these numbers better -- this was just practice before you tackle designing your own model.

# %%
torch.random.manual_seed(12345)
fixed_model.cpu()
fixed_model.apply(reset) 
fixed_model.train() 
train(fixed_model, loss_fn, optimizer,image_dataloader_train, num_epochs=1) 
check_accuracy(fixed_model, image_dataloader_train)# check accuracy on the training set
# Out:
# Starting epoch 1 / 1
# t = 100, loss = 1.7958
# t = 200, loss = 1.6411
# t = 300, loss = 1.4361
# t = 400, loss = 1.2933
# t = 500, loss = 1.1062
# t = 600, loss = 1.1775
# t = 700, loss = 1.1567
# Got 14137 / 23310 correct (60.65)

# %% [markdown]
# ### Don't forget the validation set!
#
# And note that you can use the check_accuracy function to evaluate on the validation set, by passing **image_dataloader_val** as the second argument to check_accuracy. The accuracy on validation set is arround 40-50%.

# %%
check_accuracy(fixed_model, image_dataloader_val)#check accuracy on the validation set
# Out:
# Got 3286 / 6690 correct (49.12)

# %% [markdown]
# ##### Train a better  model for action recognition!
#
# Now it's your job to experiment with architectures, hyperparameters, loss functions, and optimizers to train a model that achieves better accuracy on the action recognition **validation** set. You can use the check_accuracy and train functions from above.

# %% [markdown]
# ### Things you should try:
# - **Filter size**: Above we used 7x7; this makes pretty pictures but smaller filters may be more efficient
# - **Number of filters**: Do more or fewer do better?
# - **Pooling vs Strided Convolution**: Do you use max pooling or just stride convolutions?
# - **Batch normalization**: Try adding spatial batch normalization after convolution layers and vanilla batch normalization after affine layers. Do your networks train faster?
# - **Network architecture**: The network above has two layers of trainable parameters. Can you do better with a deep network? Good architectures to try include:
#     - [conv-relu-pool]xN -> [affine]xM -> [softmax or SVM]
#     - [conv-relu-conv-relu-pool]xN -> [affine]xM -> [softmax or SVM]
#     - [batchnorm-relu-conv]xN -> [affine]xM -> [softmax or SVM]
# - **Global Average Pooling**: Instead of flattening and then having multiple affine layers, perform convolutions until your image gets small (7x7 or so) and then perform an average pooling operation to get to a 1x1 image picture (1, 1 , Filter#), which is then reshaped into a (Filter#) vector. This is used in [Google's Inception Network](https://arxiv.org/abs/1512.00567) (See Table 1 for their architecture).
# - **Regularization**: Add l2 weight regularization, or perhaps use Dropout.
#
# ### Tips for training
# For each network architecture that you try, you should tune the learning rate and regularization strength. When doing this there are a couple important things to keep in mind:
#
# - If the parameters are working well, you should see improvement within a few hundred iterations
# - Remember the coarse-to-fine approach for hyperparameter tuning: start by testing a large range of hyperparameters for just a few training iterations to find the combinations of parameters that are working at all.
# - Once you have found some sets of parameters that seem to work, search more finely around these parameters. You may need to train for more epochs.
# - You should use the validation set for hyperparameter search, and save your test set for evaluating your architecture on the best parameters as selected by the validation set.
#
# ### Going above and beyond
# If you are feeling adventurous there are many other features you can implement to try and improve your performance. You are **not required** to implement any of these; however they would be good things to try.
#
# - Alternative update steps: For the assignment we implemented SGD+momentum, RMSprop, and Adam; you could try alternatives like AdaGrad or AdaDelta.
# - Alternative activation functions such as leaky ReLU, parametric ReLU, ELU, or MaxOut.
# - Model ensembles
# - Data augmentation
# - New Architectures
#   - [ResNets](https://arxiv.org/abs/1512.03385) where the input from the previous layer is added to the output.
#   - [DenseNets](https://arxiv.org/abs/1608.06993) where inputs into previous layers are concatenated together.
#   - [This blog has an in-depth overview](https://chatbotslife.com/resnets-highwaynets-and-densenets-oh-my-9bb15918ee32)
#
# If you do decide to implement something extra, clearly describe it in the "Extra Credit Description" cell below.
#
# ### What we expect
# At the very least, you should be able to train a ConvNet that gets at least 55% accuracy on the validation set. This is just a lower bound - if you are careful it should be possible to get accuracies much higher than that! Extra credit points will be awarded for particularly high-scoring models or unique approaches.
#
# You should use the space below to experiment and train your network.

# %%
model_base = nn.Sequential(
    
            nn.Conv2d(3, 64, kernel_size=11, stride=4, padding=5),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),
    
            nn.Conv2d(64, 192, kernel_size=5, padding=2),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),
    
            nn.Conv2d(192, 384, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(384, 256, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),

            nn.Conv2d(256, 256, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),

            Flatten(), 
            nn.Linear(1024, 10), 


    )

model = model_base.type(dtype)

x = torch.randn(32, 3, 64, 64).type(dtype)
x_var = Variable(x.type(dtype)) 
ans = model(x_var)  

print(np.array(ans.size()))
np.array_equal(np.array(ans.size()), np.array([32, 10]))   
#54
#56,4
#63,8
#,16
# Out:
# [32 10]
# True

# %%
###########3rd To Do (16 points, must submit the results to Kaggle) ##############
# Train your model here, and make sure the output of this cell is the accuracy of your best model on the 
# train, val, and test sets. Here's some code to get you started. The output of this cell should be the training
# and validation accuracy on your best model (measured by validation accuracy).

learning_rate = 0.00007
optimizer = torch.optim.Adam(model.parameters(),lr = learning_rate)
loss_fn = torch.nn.CrossEntropyLoss()
train(model_base, loss_fn, optimizer,image_dataloader_train, num_epochs=8) 
# print("checking accuracy on validation set...")
check_accuracy(model, image_dataloader_train)
check_accuracy(model, image_dataloader_val)
# Out:
# Starting epoch 1 / 8
# t = 100, loss = 1.8942
# t = 200, loss = 1.6538
# t = 300, loss = 1.5036
# t = 400, loss = 1.1201
# t = 500, loss = 1.0181
# t = 600, loss = 0.9144
# t = 700, loss = 0.7803
# Starting epoch 2 / 8
# t = 100, loss = 0.6114
# t = 200, loss = 0.6429
# t = 300, loss = 0.4742
# t = 400, loss = 0.4896
# t = 500, loss = 0.1937
# t = 600, loss = 0.5623
# t = 700, loss = 0.3731
# Starting epoch 3 / 8
# t = 100, loss = 0.3567
# t = 200, loss = 0.3721
# t = 300, loss = 0.4324
# t = 400, loss = 0.1748
# t = 500, loss = 0.0779
# t = 600, loss = 0.3652
# t = 700, loss = 0.1491
# Starting epoch 4 / 8
# t = 100, loss = 0.1044
# t = 200, loss = 0.2899
# t = 300, loss = 0.1154
# t = 400, loss = 0.0829
# t = 500, loss = 0.1222
# t = 600, loss = 0.1001
# t = 700, loss = 0.1173
# Starting epoch 5 / 8
# t = 100, loss = 0.0914
# t = 200, loss = 0.0610
# t = 300, loss = 0.1284
# t = 400, loss = 0.0936
# t = 500, loss = 0.1586
# t = 600, loss = 0.2632
# t = 700, loss = 0.1272
# Starting epoch 6 / 8
# t = 100, loss = 0.0190
# t = 200, loss = 0.0203
# t = 300, loss = 0.1018
# t = 400, loss = 0.0257
# t = 500, loss = 0.0237
# t = 600, loss = 0.0607
# t = 700, loss = 0.0367
# Starting epoch 7 / 8
# t = 100, loss = 0.0670
# t = 200, loss = 0.1399
# t = 300, loss = 0.0143
# t = 400, loss = 0.1676
# t = 500, loss = 0.0221
# t = 600, loss = 0.0312
# t = 700, loss = 0.0633
# Starting epoch 8 / 8
# t = 100, loss = 0.0266
# t = 200, loss = 0.1175
# t = 300, loss = 0.0817
# t = 400, loss = 0.0071
# t = 500, loss = 0.0192
# t = 600, loss = 0.0333
# t = 700, loss = 0.1076
# Got 23087 / 23310 correct (99.04)
# Got 4147 / 6690 correct (61.99)

# %% [markdown]
# ### Describe what you did
#
# In the cell below you should write an explanation of what you did, any additional features that you implemented, and any visualizations or graphs that you make in the process of training and evaluating your network.

# %% [markdown]
# Tell us here!
# ###########4th To Do (4 points) ##############
# As suggested in the comments to experiment with different architectures (like resnet or alexnet), one of the architecture that seemed to work better than others was this architecture-
#
# [conv-relu-pool]xN -> [affine]xM -> [softmax or SVM]
# Multiple conv-relu-pool layers followed by 1 affine layer.
# Also, smaller Kernel size worked better than larger kernel sizes, so I used kernels smaller kernels with stride = 1 or whenever I used larger Kernel size = 5/11, I used higher stride = 2/4.

# %% [markdown]
# ### Testing the model and submit on Kaggle
# Testing the model on the testing set and save the results as a .csv file.
# Please submitted the results.csv file generated by predict_on_test() to Kaggle(https://www.kaggle.com/c/cse512springhw3) to see how well your network performs on the test set.
# #######5th To Do (submit the result to Kaggle,the highest 3 entries get extra 10 points )###############
# Accuracy-64.26095%

# %%
def predict_on_test(model, loader):
    '''
    if loader.dataset.train:
        print('Checking accuracy on validation set')
    else:
        print('Checking accuracy on test set')  
    '''
    num_correct = 0
    num_samples = 0
    model.eval() # Put the model in test mode (the opposite of model.train(), essentially)
    results=open('results.csv','w')
    count=0
    results.write('Id'+','+'Class'+'\n')
    for t, sample in enumerate(loader):
        x_var = Variable(sample['image'])
        scores = model(x_var)
        _, preds = scores.data.max(1)
        for i in range(len(preds)):
            results.write(str(count)+','+str(preds[i])+'\n')
            count+=1
    results.close()
    return count
    
count=predict_on_test(model, image_dataloader_test)
print(count)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-37-be92e197fabb> in <module>()
#      22     return count
#      23
# ---> 24 count=predict_on_test(model, image_dataloader_test)
#      25 print(count)
#
# <ipython-input-37-be92e197fabb> in predict_on_test(model, loader)
#      14     for t, sample in enumerate(loader):
#      15         x_var = Variable(sample['image'])
# ---> 16         scores = model(x_var)
#      17         _, preds = scores.data.max(1)
#      18         for i in range(len(preds)):
#
# /Users/krishnasharma/Documents/hw3/code-data-hw3/.env/lib/python2.7/site-packages/torch/nn/modules/module.pyc in __call__(self, *input, **kwargs)
#     355             result = self._slow_forward(*input, **kwargs)
#     356         else:
# --> 357             result = self.forward(*input, **kwargs)
#     358         for hook in self._forward_hooks.values():
#     359             hook_result = hook(self, input, result)
#
# /Users/krishnasharma/Documents/hw3/code-data-hw3/.env/lib/python2.7/site-packages/torch/nn/modules/container.pyc in forward(self, input)
#      65     def forward(self, input):
#      66         for module in self._modules.values():
# ---> 67             input = module(input)
#      68         return input
#      69
#
# /Users/krishnasharma/Documents/hw3/code-data-hw3/.env/lib/python2.7/site-packages/torch/nn/modules/module.pyc in __call__(self, *input, **kwargs)
#     355             result = self._slow_forward(*input, **kwargs)
#     356         else:
# --> 357             result = self.forward(*input, **kwargs)
#     358         for hook in self._forward_hooks.values():
#     359             hook_result = hook(self, input, result)
#
# /Users/krishnasharma/Documents/hw3/code-data-hw3/.env/lib/python2.7/site-packages/torch/nn/modules/conv.pyc in forward(self, input)
#     386     def forward(self, input):
#     387         return F.conv3d(input, self.weight, self.bias, self.stride,
# --> 388                         self.padding, self.dilation, self.groups)
#     389
#     390
#
# /Users/krishnasharma/Documents/hw3/code-data-hw3/.env/lib/python2.7/site-packages/torch/nn/functional.pyc in conv3d(input, weight, bias, stride, padding, dilation, groups)
#     119
#     120     if input is not None and input.dim() != 5:
# --> 121         raise ValueError("Expected 5D tensor as input, got {}D tensor instead.".format(input.dim()))
#     122
#     123     f = _ConvNd(_triple(stride), _triple(padding), _triple(dilation), False,
#
# ValueError: Expected 5D tensor as input, got 4D tensor instead.

# %% [markdown]
# ### GPU! (This part is optional, 0 points)
#
# If you have access to GPU, you can make the code run on GPU, it would be much faster.
#
# Now, we're going to switch the dtype of the model and our data to the GPU-friendly tensors, and see what happens... everything is the same, except we are casting our model and input tensors as this new dtype instead of the old one.
#
# If this returns false, or otherwise fails in a not-graceful way (i.e., with some error message), you may not have an NVIDIA GPU available on your machine.

# %%
# Verify that CUDA is properly configured and you have a GPU available

# torch.cuda.is_available()

# %%
import copy
# gpu_dtype = torch.cuda.FloatTensor

fixed_model_gpu = copy.deepcopy(fixed_model_base)#.type(gpu_dtype)
# fixed_model_gpu.cuda()
x_gpu = torch.randn(4, 3, 64, 64).cuda()#.type(gpu_dtype)
x_var_gpu = Variable(x_gpu)#type(gpu_dtype)) # Construct a PyTorch Variable out of your input data
ans = fixed_model_gpu(x_var_gpu)        # Feed it through the model! 

# Check to make sure what comes out of your model
# is the right dimensionality... this should be True
# if you've done everything correctly
np.array_equal(np.array(ans.size()), np.array([4, 10]))

# %% [markdown]
# Run the following cell to evaluate the performance of the forward pass running on the CPU:

# %%
# %%timeit 
ans = fixed_model(x_var)

# %% [markdown]
# ... and now the GPU:

# %%
# %%timeit 
torch.cuda.synchronize() # Make sure there are no pending GPU computations
ans = fixed_model_gpu(x_var_gpu)        # Feed it through the model! 
torch.cuda.synchronize() # Make sure there are no pending GPU computations

# %% [markdown]
# You should observe that even a simple forward pass like this is significantly faster on the GPU. So for the rest of the assignment (and when you go train your models in assignment 3 and your project!), you should use the GPU datatype for your model and your tensors: as a reminder that is *torch.cuda.FloatTensor* (in our notebook here as *gpu_dtype*)

# %% [markdown]
# Let's make the loss function and training variables to GPU friendly format by '.cuda()'

# %%
loss_fn = nn.CrossEntropyLoss().cuda()
optimizer = optim.RMSprop(fixed_model_gpu.parameters(), lr=1e-4)

# %%
def train(model, loss_fn, optimizer, dataloader, num_epochs = 1):
    for epoch in range(num_epochs):
        print('Starting epoch %d / %d' % (epoch + 1, num_epochs))
        model.train()
        for t, sample in enumerate(dataloader):
            x_var = Variable(sample['image'].cuda())
            y_var = Variable(sample['Label'].cuda().long())

            scores = model(x_var)
            
            loss = loss_fn(scores, y_var)
            if (t + 1) % print_every == 0:
                print('t = %d, loss = %.4f' % (t + 1, loss.data[0]))

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

def check_accuracy(model, loader):
    '''
    if loader.dataset.train:
        print('Checking accuracy on validation set')
    else:
        print('Checking accuracy on test set')  
    '''
    num_correct = 0
    num_samples = 0
    model.eval() # Put the model in test mode (the opposite of model.train(), essentially)
    for t, sample in enumerate(loader):
        x_var = Variable(sample['image'].cuda())
        y_var = sample['Label'].cuda()
        y_var=y_var.cpu()
        scores = model(x_var)
        _, preds = scores.data.cpu().max(1)
        #print(preds)
        #print(y_var)
        num_correct += (preds.numpy() == y_var.numpy()).sum()
        num_samples += preds.size(0)
    acc = float(num_correct) / num_samples
    print('Got %d / %d correct (%.2f)' % (num_correct, num_samples, 100 * acc))

# %% [markdown]
# Run on GPU!

# %%
torch.cuda.random.manual_seed(12345)

fixed_model_gpu.apply(reset) 
fixed_model_gpu.train() 
train(fixed_model_gpu, loss_fn, optimizer,image_dataloader_train, num_epochs=1) 
check_accuracy(fixed_model_gpu, image_dataloader_train)# check accuracy on the training set

# %% [markdown]
# ### 3D Convolution on video clips (25 points+10 extra points)
# 3D convolution is for videos, it has one more dimension than 2d convolution. You can find the document for 3D convolution here http://pytorch.org/docs/master/nn.html#torch.nn.Conv3dIn. In our dataset, each clip is a video of 3 frames. Lets classify the each clip rather than each image using 3D convolution.
# We offer the data loader, the train_3d and check_accuracy

# %%
class ActionClipDataset(Dataset):
    """Action Landmarks dataset."""

    def __init__(self,  root_dir,labels=[], transform=None):
        """
        Args:
            csv_file (string): Path to the csv file with annotations.
            root_dir (string): Directory with all the images.
            transform (callable, optional): Optional transform to be applied
                on a sample.
        """
        
        self.root_dir = root_dir
        self.transform = transform
        self.length=len(os.listdir(self.root_dir))
        self.labels=labels

    def __len__(self):
        return self.length

    def __getitem__(self, idx):
        
        folder=idx+1
        folder=format(folder,'05d')
        clip=[]
        if len(self.labels)!=0:
            Label=self.labels[idx][0]-1
        for i in range(3):
            imidx=i+1
            imgname=str(imidx)+'.jpg'
            img_path = os.path.join(self.root_dir,
                                    folder,imgname)
            image = Image.open(img_path)
            image=np.array(image)
            clip.append(image)
        if self.transform:
            clip=np.asarray(clip)
            clip=np.transpose(clip, (0,3,1,2))
            clip = torch.from_numpy(np.asarray(clip))
        if len(self.labels)!=0:
            sample={'clip':clip,'Label':Label,'folder':folder}
        else:
            sample={'clip':clip,'folder':folder}
        return sample

clip_dataset=ActionClipDataset(root_dir='./data/trainClips/',\
                               labels=label_train,transform=T.ToTensor())#/home/tqvinh/Study/CSE512/cse512-s18/hw2data/trainClips/
for i in range(10):
    sample=clip_dataset[i]
    print(sample['clip'].shape)
    print(sample['Label'])
    print(sample['folder'])
# Out:
# torch.Size([3, 3, 64, 64])
# 0.0
# 00001
# torch.Size([3, 3, 64, 64])
# 0.0
# 00002
# torch.Size([3, 3, 64, 64])
# 0.0
# 00003
# torch.Size([3, 3, 64, 64])
# 0.0
# 00004
# torch.Size([3, 3, 64, 64])
# 0.0
# 00005
# torch.Size([3, 3, 64, 64])
# 0.0
# 00006
# torch.Size([3, 3, 64, 64])
# 0.0
# 00007
# torch.Size([3, 3, 64, 64])
# 0.0
# 00008
# torch.Size([3, 3, 64, 64])
# 0.0
# 00009
# torch.Size([3, 3, 64, 64])
# 0.0
# 00010

# %%
clip_dataloader = DataLoader(clip_dataset, batch_size=4,
                        shuffle=True, num_workers=4)


for i,sample in enumerate(clip_dataloader):
    print(i,sample['clip'].shape,sample['folder'],sample['Label'])
    if i>20: 
        break
# Out:
# (0, torch.Size([4, 3, 3, 64, 64]), ['06207', '06588', '03570', '02207'],
#  7
#  8
#  4
#  2
# [torch.DoubleTensor of size 4]
# )
# (1, torch.Size([4, 3, 3, 64, 64]), ['05315', '05371', '06023', '05674'],
#  6
#  6
#  7
#  7
# [torch.DoubleTensor of size 4]
# )
# (2, torch.Size([4, 3, 3, 64, 64]), ['07604', '00669', '07683', '02454'],
#  9
#  0
#  9
#  2
# [torch.DoubleTensor of size 4]
# )
# (3, torch.Size([4, 3, 3, 64, 64]), ['03833', '03849', '06094', '01458'],
#  4
#  4
#  7
#  1
# [torch.DoubleTensor of size 4]
# )
# (4, torch.Size([4, 3, 3, 64, 64]), ['06558', '01523', '06726', '03562'],
#  8
#  1
#  8
#  4
# [torch.DoubleTensor of size 4]
# )
# (5, torch.Size([4, 3, 3, 64, 64]), ['01847', '07016', '02933', '02134'],
#  2
#  8
#  3
#  2
# [torch.DoubleTensor of size 4]
# )
# (6, torch.Size([4, 3, 3, 64, 64]), ['01698', '07720', '03319', '07728'],
#  1
#  9
#  3
#  9
# [torch.DoubleTensor of size 4]
# )
# (7, torch.Size([4, 3, 3, 64, 64]), ['06084', '04878', '03697', '01956'],
#  7
#  5
#  4
#  2
# [torch.DoubleTensor of size 4]
# )
# (8, torch.Size([4, 3, 3, 64, 64]), ['04417', '00054', '05671', '04562'],
#  5
#  0
#  7
#  5
# [torch.DoubleTensor of size 4]
# )
# (9, torch.Size([4, 3, 3, 64, 64]), ['03573', '01383', '05742', '05564'],
#  4
#  1
#  7
#  6
# [torch.DoubleTensor of size 4]
# )
# (10, torch.Size([4, 3, 3, 64, 64]), ['06772', '01125', '05393', '05865'],
#  8
#  1
#  6
#  7
# [torch.DoubleTensor of size 4]
# )
# (11, torch.Size([4, 3, 3, 64, 64]), ['00797', '04679', '05171', '00386'],
#  0
#  5
#  6
#  0
# [torch.DoubleTensor of size 4]
# )
# (12, torch.Size([4, 3, 3, 64, 64]), ['02805', '07316', '03112', '00862'],
#  3
#  9
#  3
#  0
# [torch.DoubleTensor of size 4]
# )
# (13, torch.Size([4, 3, 3, 64, 64]), ['05953', '06544', '04142', '07710'],
#  7
#  8
#  4
#  9
# [torch.DoubleTensor of size 4]
# )
# (14, torch.Size([4, 3, 3, 64, 64]), ['01329', '04992', '07374', '01513'],
#  1
#  6
#  9
#  1
# [torch.DoubleTensor of size 4]
# )
# (15, torch.Size([4, 3, 3, 64, 64]), ['03000', '01339', '01647', '02446'],
#  3
#  1
#  1
#  2
# [torch.DoubleTensor of size 4]
# )
# (16, torch.Size([4, 3, 3, 64, 64]), ['04048', '07524', '02284', '02844'],
#  4
#  9
#  2
#  3
# [torch.DoubleTensor of size 4]
# )
# (17, torch.Size([4, 3, 3, 64, 64]), ['05818', '04672', '01929', '02383'],
#  7
#  5
#  2
#  2
# [torch.DoubleTensor of size 4]
# )
# (18, torch.Size([4, 3, 3, 64, 64]), ['01885', '07112', '04367', '07416'],
#  2
#  8
#  5
#  9
# [torch.DoubleTensor of size 4]
# )
# (19, torch.Size([4, 3, 3, 64, 64]), ['05603', '06221', '02484', '02879'],
#  6
#  7
#  2
#  3
# [torch.DoubleTensor of size 4]
# )
# (20, torch.Size([4, 3, 3, 64, 64]), ['07384', '07383', '03980', '06747'],
#  9
#  9
#  4
#  8
# [torch.DoubleTensor of size 4]
# )
# (21, torch.Size([4, 3, 3, 64, 64]), ['05715', '00985', '02098', '03169'],
#  7
#  1
#  2
#  3
# [torch.DoubleTensor of size 4]
# )

# %%
clip_dataset_train=ActionClipDataset(root_dir='./data/trainClips/',labels=label_train,transform=T.ToTensor())

clip_dataloader_train = DataLoader(clip_dataset_train, batch_size=16,
                        shuffle=True, num_workers=4)
clip_dataset_val=ActionClipDataset(root_dir='./data/valClips/',labels=label_val,transform=T.ToTensor())

clip_dataloader_val = DataLoader(clip_dataset_val, batch_size=16,
                        shuffle=True, num_workers=4)
clip_dataset_test=ActionClipDataset(root_dir='./data/testClips/',labels=[],transform=T.ToTensor())

clip_dataloader_test = DataLoader(clip_dataset_test, batch_size=16,
                        shuffle=False, num_workers=4)

# %% [markdown]
# Write the Flatten for 3d covolution feature maps.

# %%
 ###############6th To Do (5 points)###################
class Flatten3d(nn.Module):
    def forward(self, x):
        N, clips,C, H, W = x.size() # read in N, C, H, W
        return x.view(N, -1)

# %% [markdown]
# Design a network using 3D convolution on videos for video classification.

# %%
fixed_model_3d = nn.Sequential( # You fill this in!
    ###############7th To Do (16 points)#########################
         #init
                nn.Conv3d(3, 16, kernel_size=7,stride=(1, 2, 2), padding=(3, 3, 3), bias=False),
                nn.BatchNorm3d(16),
                nn.ReLU(inplace=True),
                nn.MaxPool3d(kernel_size=3, stride=2, padding=1),
        #layer1
                nn.BatchNorm3d(16),
                nn.ReLU(inplace=True),
                nn.Conv3d(16, 32,kernel_size=1, stride=1, bias=False),

                nn.BatchNorm3d(32),
                nn.ReLU(inplace=True),
                nn.Conv3d(32, 64,kernel_size=3, stride=1, padding=1, bias=False),

#     layer2
                nn.BatchNorm3d(64),
                nn.ReLU(inplace=True),
                nn.Conv3d(64, 128,kernel_size=(1,7,7), stride=1, bias=False),

                nn.BatchNorm3d(128),
                nn.ReLU(inplace=True),
                nn.Conv3d(128,256,kernel_size=(3,4,4), stride=2, padding=1, bias=False),

                
    #final layer
    
                nn.BatchNorm2d(256),
                Flatten3d(),
                nn.Linear(6400, 10),
        )


fixed_model_3d = fixed_model_3d.type(dtype)
model = fixed_model_3d
x = torch.randn(32, 3,3, 64, 64).type(dtype)
x_var = Variable(x.type(dtype)) 
ans = model(x_var)  

print(np.array(ans.size()))
np.array_equal(np.array(ans.size()), np.array([32, 10]))
# Out:
# [32 10]
# True

# %% [markdown]
# ### Describe what you did (4 points)
#
# In the cell below you should write an explanation of what you did, any additional features that you implemented, and any visualizations or graphs that you make in the process of training and evaluating your network.

# %% [markdown]
# 8th To Do
# Tell us here:
# After experimenting with several different architectures including architectures of resnet and alexnet and
# [batchnorm-relu-conv]xN -> [affine]xM -> [softmax or SVM]
# seemed to work best among all of the models. Smaller Kernel sizes(1,2 or 3) worked better than larger kernels, whenever I used larger kernels I ensured larger strides and padding.
# Extra care was taken during specifying kernel size in 3 dimensions, so as to ensure that one of the dimension does not reduce to 0 during convolution or pooling.

# %%
loss_fn = nn.CrossEntropyLoss().type(dtype)
optimizer = optim.RMSprop(fixed_model_3d.parameters(), lr=1e-4)

# %%
def train_3d(model, loss_fn, optimizer,dataloader,num_epochs = 1):
    for epoch in range(num_epochs):
        print('Starting epoch %d / %d' % (epoch + 1, num_epochs))
        model.train()
        for t, sample in enumerate(dataloader):
            x_var = Variable(sample['clip'].type(dtype))
            y_var = Variable(sample['Label'].type(dtype).long())

            scores = model(x_var)
            
            loss = loss_fn(scores, y_var)
            if (t + 1) % print_every == 0:
                print('t = %d, loss = %.4f' % (t + 1, loss.data[0]))

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

def check_accuracy_3d(model, loader):
    '''
    if loader.dataset.train:
        print('Checking accuracy on validation set')
    else:
        print('Checking accuracy on test set')  
    '''
    num_correct = 0
    num_samples = 0
    model.eval() # Put the model in test mode (the opposite of model.train(), essentially)
    for t, sample in enumerate(loader):
        x_var = Variable(sample['clip'].type(dtype))
        y_var = sample['Label'].type(dtype)
        y_var=y_var.cpu()
        scores = model(x_var)
        _, preds = scores.data.cpu().max(1)
        #print(preds)
        #print(y_var)
        num_correct += (preds.numpy() == y_var.numpy()).sum()
        num_samples += preds.size(0)
    acc = float(num_correct) / num_samples
    print('Got %d / %d correct (%.2f)' % (num_correct, num_samples, 100 * acc))

# %%
#torch.cuda.random.manual_seed(12345)
fixed_model_3d.apply(reset) 
fixed_model_3d.train() 
train_3d(fixed_model_3d, loss_fn, optimizer,clip_dataloader_train, num_epochs=5) 
fixed_model_3d.eval() 
check_accuracy_3d(fixed_model_3d, clip_dataloader_val)
# Out:
# Starting epoch 1 / 5
# t = 100, loss = 0.8192
# t = 200, loss = 0.2835
# t = 300, loss = 0.2238
# t = 400, loss = 0.1019
# Starting epoch 2 / 5
# t = 100, loss = 0.0558
# t = 200, loss = 0.0417
# t = 300, loss = 0.0157
# t = 400, loss = 0.0373
# Starting epoch 3 / 5
# t = 100, loss = 0.0672
# t = 200, loss = 0.0775
# t = 300, loss = 0.0619
# t = 400, loss = 0.0441
# Starting epoch 4 / 5
# t = 100, loss = 0.0097
# t = 200, loss = 0.0193
# t = 300, loss = 0.0389
# t = 400, loss = 0.0042
# Starting epoch 5 / 5
# t = 100, loss = 0.0779
# t = 200, loss = 0.0107
# t = 300, loss = 0.0016
# t = 400, loss = 0.0009
# Got 1482 / 2230 correct (66.46)

# %%
check_accuracy_3d(fixed_model_3d, clip_dataloader_train)
# check_accuracy_3d(fixed_model_3d, clip_dataloader_val)

# %% [markdown]
# Test your 3d convolution model on the validation set. You don't need to submit the result of this part to kaggle.

# %% [markdown]
# Test your model on the test set, predict_on_test_3d() will generate a file named 'results_3d.csv'. Please submit the csv file to kaggle https://www.kaggle.com/c/cse512springhw3video
# The highest 3 entries get extra 10 points.
# Accuracy-65.13761%

# %%
def predict_on_test_3d(model, loader):
    '''
    if loader.dataset.train:
        print('Checking accuracy on validation set')
    else:
        print('Checking accuracy on test set')  
    '''
    num_correct = 0
    num_samples = 0
    model.eval() # Put the model in test mode (the opposite of model.train(), essentially)
    results=open('results_3d.csv','w')
    count=0
    results.write('Id'+','+'Class'+'\n')
    for t, sample in enumerate(loader):
        x_var = Variable(sample['clip'].type(dtype))
        scores = model(x_var)
        _, preds = scores.data.max(1)
        for i in range(len(preds)):
            results.write(str(count)+','+str(preds[i])+'\n')
            count+=1
    results.close()
    return count
    
count=predict_on_test_3d(fixed_model_3d, clip_dataloader_test)
print(count)
# Out:
# 3270
